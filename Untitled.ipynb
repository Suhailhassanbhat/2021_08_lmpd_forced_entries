# %%
import geopandas as gpd

# %%
df=gpd.read_file("forced_entry.geojson")

# %%
new_df=df[df.reason == "Search Warrant"]

# %%
new_df.to_file("sw_forced_entry.geojson", driver="GeoJSON", index=False)

# %%
gpd.read_file("sw_forced_entry.geojson")
# Out:
#     year        date      time          id          reason knock_and_announce  \
# 0   2019  2019-09-04  17:20:00  8019065461  Search Warrant      Announce Only
# 1   2019  2019-09-04  17:30:00  8019065461  Search Warrant      Announce Only
# 2   2019  2019-09-05  14:00:00  8019065701  Search Warrant      Not Available
# 3   2019  2019-09-05  19:30:00  8019065798  Search Warrant                Yes
# 4   2019  2019-09-11  15:00:00  8019067288  Search Warrant                Yes
# ..   ...         ...       ...         ...             ...                ...
# 63  2020  2020-05-12  16:00:00  8020028130  Search Warrant                Yes
# 64  2020  2020-05-19  15:11:00  8020029467  Search Warrant                Yes
# 65  2020  2020-12-16  13:30:00  8021074509  Search Warrant                Yes
# 66  2021  2021-01-26  10:40:00  8021005149  Search Warrant      Not Available
# 67  2021  2021-07-09  23:56:00  8021039902  Search Warrant                Yes
#
# ...
